# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# importing Liberary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

import warnings
warnings.filterwarnings('ignore')

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))

# %%
#reading the cleaned data in EDA
df = pd.read_csv("../data/raw/data.csv")

# %%
df = df.copy()
df
# Out:
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          256
# 1      SubscriptionId_3829  CustomerId_4406          UGX          256
# ...

# %% [markdown]
# ## Overview of the Data:
# ○	Understand the structure of the dataset, including the number of rows, columns, and data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95662 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  object
#  14  PricingStrategy       95662 non-null  int64
# ...

# %% [markdown]
# ## Summary Statistics
# ○	Understand the central tendency, dispersion, and shape of the dataset’s distribution.

# %%
df.describe()
# Out:
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %%
df.isnull().sum()
# Out:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %%
# Count the occurrences of each unique value in 'FraudResult'
value_counts = df['FraudResult'].value_counts()

value_counts
# Out:
# FraudResult
# 0    95469
# 1      193
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution of Numerical Features
# ○	Visualize the distribution of numerical features to identify patterns, skewness, and potential outliers.

# %%
# Plotting histogram for Amount
plt.figure(figsize=(8, 6))
df['Amount'].hist(bins=10, edgecolor='black', color='skyblue')

# Adding title and labels
plt.title('Histogram of Amount', fontsize=16)
plt.xlabel('Amount', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show plot
plt.show()

# %%
# Plotting histogram for Value
plt.figure(figsize=(8, 6))
df['Value'].hist(bins=10, edgecolor='black', color='skyblue')

# Adding title and labels
plt.title('Histogram of Amount', fontsize=16)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show plot
plt.show()

# %%
# Plotting histogram for PricingStrategy
plt.figure(figsize=(8, 6))
df['PricingStrategy'].hist(bins=10, edgecolor='black', color='skyblue')

# Adding title and labels
plt.title('Histogram of PricingStrategy', fontsize=16)
plt.xlabel('PricingStrategy', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show plot
plt.show()

# %%
# Plotting the bar graph
plt.figure(figsize=(8, 6))
ax = value_counts.plot(kind='bar', color='skyblue')

# Adding labels and title
plt.title('Counts of FraudResult', fontsize=16)
plt.xlabel('Fraud Result', fontsize=14)
plt.ylabel('Counts', fontsize=14)

# Adding count labels on top of each bar
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# Display the plot
plt.show()

# %% [markdown]
# ## Correlation Analysis
#
# ○	Understanding the relationship between numerical features.

# %%
# Computing the correlation matrix for the selected variables
correlation_matrix = df[['CountryCode', 'Amount', 'Value', 'PricingStrategy', 'FraudResult']].corr()

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Adding title
plt.title('Correlation Heatmap of Selected Variables', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# ## 	Distribution of Categorical Features
# ○	Analyzing the distribution of categorical features provides insights into the frequency and variability of categories.

# %%
# Count frequency of each category
frequency_df = df['TransactionId'].value_counts().reset_index()
frequency_df.columns = ['TransactionId', 'Frequency']

# Plotting bar plot using seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x='TransactionId', y='Frequency', data=frequency_df, palette='Blues_d')

# Adding labels and title
plt.title('Bar Plot of TransactionId and Frequencies', fontsize=16)
plt.xlabel('TransactionId', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.show()

# %%
# Count frequency of each category
BatchId_df = df['BatchId'].value_counts().reset_index()
BatchId_df.columns = ['BatchId', 'Frequency']

# Plotting bar plot using seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x='BatchId', y='Frequency', data=BatchId_df, palette='Blues_d')

# Adding labels and title
plt.title('Bar Plot of BatchId and Frequencies', fontsize=16)
plt.xlabel('BatchId', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.show()

# %%
# Count frequency of each category
StartTime_df = df['ProductCategory'].value_counts().reset_index()
StartTime_df.columns = ['ProductCategory', 'Frequency']

# Plotting bar plot using seaborn
plt.figure(figsize=(8, 6))
sns.barplot(x='ProductCategory', y='Frequency', data=StartTime_df, palette='Blues_d')

# Adding labels and title
plt.title('Bar Plot of TransactionStartTime and Frequencies', fontsize=16)
plt.xlabel('TransactionStartTime', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Show the plot
plt.show()

# %%
# Count frequency of each category
ProductCategory_df = df['ProductCategory'].value_counts().reset_index()
ProductCategory_df.columns = ['ProductCategory', 'Frequency']

# Plotting bar plot using seaborn
plt.figure(figsize=(8, 6))
barplot = sns.barplot(x='ProductCategory', y='Frequency', data=ProductCategory_df, palette='Blues_d')

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)

# Adding values on top of each bar
for index, row in ProductCategory_df.iterrows():
    barplot.text(index, row['Frequency'], round(row['Frequency'], 2), color='black', ha="center", va="bottom")

# Adding labels and title
plt.title('Bar Plot of ProductCategory and Frequencies', fontsize=16)
plt.xlabel('ProductCategory', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Adjust layout to avoid label overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Outlier Detection
# ○	Use box plots to identify outliers.

# %%
# Plotting boxplot for Amount
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Amount'], color='skyblue')

# Adding title and labels
plt.title('Boxplot of Amount', fontsize=16)
plt.xlabel('Amount', fontsize=14)

# Show plot
plt.show()

# %%
# Plotting boxplot for Value
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Value'], color='skyblue')

# Adding title and labels
plt.title('Boxplot of Value', fontsize=16)
plt.xlabel('Value', fontsize=14)

# Show plot
plt.show()

# %%
# Plotting boxplot for PricingStrategy
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['PricingStrategy'], color='skyblue')

# Adding title and labels
plt.title('Boxplot of PricingStrategy', fontsize=16)
plt.xlabel('PricingStrategy', fontsize=14)

# Show plot
plt.show()

# %%
# Plotting boxplot for FraudResult
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['FraudResult'], color='skyblue')

# Adding title and labels
plt.title('Boxplot of FraudResult', fontsize=16)
plt.xlabel('Fraud Result', fontsize=14)

# Show the plot
plt.show()
